# %%
#This is a comment
name = "Vyas Jagan"
age = 20
print(f'Hello, my name is {name} and my age is {age}')
# Out:
# Hello, my name is Vyas Jagan and my age is 20

# %% [markdown]
# |Language|Difficulity|Use Case|Popularity|
# |:------:|:---------:|:------:|:--------:|
# |Python|Beginner|Data Science|⭐⭐⭐⭐⭐|
# |Javascript|Beginner|Web Development|⭐⭐⭐⭐⭐|
# |C++|Advanced|System Programming|⭐⭐⭐|
# |R|Intermediate|Statistics , Data Analysis|⭐⭐⭐|

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# Create the _figure directory if it doesn't exist
os.makedirs('auxiliary_files', exist_ok=True)

x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)

# Create a simple plot
plt.figure(figsize=(8, 6))
plt.plot(x, y, 'b-', linewidth=2, label='sin(x)')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.title('Simple Sine Wave')
plt.grid(True, alpha=0.3)
plt.legend()
plt.savefig('auxiliary_files/sine_wave.svg', bbox_inches='tight')
plt.close()

print("Figure saved to auxiliary_files/sine_wave.svg")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Figure saved to auxiliary_files/sine_wave.svg

# %% [markdown]
# ![Sine Wave from Task2](./auxiliary_files/sine_wave.svg)

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([1,4,7,9])

# %%
A = [[1, 2, 1, 1],
     [2, 3, 2, 2],
     [1, 2, 1, 1],
     [1, 2, 1, 1]]

plt.matshow(A)
plt.show()

# %%
A = np.random.rand(100, 100)
plt.matshow(A)
plt.show()

# %%
def linear(x):
    return x + 0.5

def quadratic(x):
    return x**2

def exponential(x):
    return np.exp(x)

def sine(x):
    return np.sin(x)

x = np.linspace(0, 2, 100)

# %%
fig, ax = plt.subplots(2, 2, figsize=(8, 6))
ax[0, 0].plot(x, linear(x), color='blue', label='linear')
ax[0, 1].plot(x, quadratic(x), color='orange', label='quadratic')
ax[1, 0].plot(x, exponential(x), color='green', label='exponential')
ax[1, 1].plot(x, sine(x), color='red', label='sine')
[ax[i, j].legend() for i in range(2) for j in range(2)]
[ax[i, j].grid(True) for i in range(2) for j in range(2)]
plt.show()

# %%
fig, ax = plt.subplots(2, 2, figsize=(8, 6), sharex=True, sharey=True)
ax[0, 0].plot(x, linear(x), color='blue', label='linear')
ax[0, 1].plot(x, quadratic(x), color='orange', label='quadratic')
ax[1, 0].plot(x, exponential(x), color='green', label='exponential')
ax[1, 1].plot(x, sine(x), color='red', label='sine')
[ax[i, j].legend() for i in range(2) for j in range(2)]
[ax[i, j].grid(True) for i in range(2) for j in range(2)]
plt.show()

# %%
plt.plot(x, linear(x), label='linear')
plt.plot(x, quadratic(x), label='quadratic')
plt.plot(x, exponential(x), label='exponential')
plt.plot(x, sine(x), label='sine')
plt.legend()
plt.grid(True)
plt.show()

# %%
squares = []
for i in range(10):
    squares.append(i**2)

print(squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
squares = [i ** 2 for i in range(10)]

print(squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
squares_dict = {}
for i in range(10):
    squares_dict[i] = i ** 2

print(squares_dict)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %%
squares_dict = {i: i ** 2 for i in range(10)}

print(squares_dict)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %%
my_list = [1, 2, 3, 4, 5]
new_list = [i/2 for i in my_list]
print(new_list)
# Out:
# [0.5, 1.0, 1.5, 2.0, 2.5]

# %%
my_list = [1, 2, 3, 4, 5]
new_list = {i:i/2 for i in my_list}
print(new_list)
# Out:
# {1: 0.5, 2: 1.0, 3: 1.5, 4: 2.0, 5: 2.5}
